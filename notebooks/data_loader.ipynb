# %%
# importing diffwave functions
# In dataset I removed the spectrogram part for now
import dataset
import params

# and some libraries
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile
import numpy as np

# %%
dataloader = dataset.from_path(['..\\data\\LJ028'], params.params)

# %%
dataloader.dataset[0]
# Out:
# {'audio': tensor([-0.0014, -0.0010, -0.0011,  ...,  0.0003,  0.0005,  0.0006])}

# %%
# The rest is not important for now

# %%
plt.plot(dataloader.dataset[0]['audio'])
plt.show()
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sample_rate, samples = wavfile.read('..\\..\\LJSpeech-1.1\\LJSpeech-1.1\\wavs')
frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jwisn\OneDrive\Dokumenty\DTU\Deep_learning\project\2022-DTU-Deep-Learning-Speech-Synthesis\notebooks\data_loader.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jwisn/OneDrive/Dokumenty/DTU/Deep_learning/project/2022-DTU-Deep-Learning-Speech-Synthesis/notebooks/data_loader.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> sample_rate, samples = wavfile.read('..\\..\\LJSpeech-1.1\\LJSpeech-1.1\\wavs')
#       <a href='vscode-notebook-cell:/c%3A/Users/jwisn/OneDrive/Dokumenty/DTU/Deep_learning/project/2022-DTU-Deep-Learning-Speech-Synthesis/notebooks/data_loader.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)
#
# NameError: name 'wavfile' is not defined

# %%
plt.pcolormesh(times, frequencies, np.log(spectrogram))
plt.imshow(np.log(spectrogram))
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
